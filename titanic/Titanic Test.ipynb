# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
data.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col0 {
#             background-color:  #ffff66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col1 {
#             background-color:  #cee666;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col1 {
#             background-color:  #ffff66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col2 {
#             background-color:  #ffff66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col0 {
#             background-color:  #60b066;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col1 {
#             background-color:  #dfef66;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col2 {
#             background-color:  #90c866;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col0 {
#             background-color:  #008066;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col1 {
#             background-color:  #008066;
#         }    #T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col0" class="data row0 col0" >80</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col1" class="data row0 col1" >136</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col0" class="data row1 col0" >97</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col1" class="data row1 col1" >87</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col0" class="data row2 col0" >372</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col1" class="data row2 col1" >119</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col0" class="data row3 col0" >549</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col1" class="data row3 col1" >342</td>
#         <td id="T_fe9a9696_6805_11e8_bcd6_d07e353b3c60row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col0 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col1 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col2 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col3 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col4 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col5 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col6 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col7 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col8 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col9 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col10 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col11 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col12 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col13 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col14 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col15 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col16 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col0 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col1 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col2 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col3 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col4 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col5 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col6 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col7 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col8 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col9 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col10 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col11 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col12 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col13 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col14 {
#             background-color:  #ffff66;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col15 {
#             background-color:  #008066;
#         }    #T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col0" class="data row0 col0" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col1" class="data row0 col1" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col2" class="data row0 col2" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col3" class="data row0 col3" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col4" class="data row0 col4" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col5" class="data row0 col5" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col6" class="data row0 col6" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col7" class="data row0 col7" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col8" class="data row0 col8" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col9" class="data row0 col9" >182</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col10" class="data row0 col10" >2</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col11" class="data row0 col11" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col12" class="data row0 col12" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col13" class="data row0 col13" >125</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col14" class="data row0 col14" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col15" class="data row0 col15" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col0" class="data row1 col0" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col1" class="data row1 col1" >2</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col2" class="data row1 col2" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col3" class="data row1 col3" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col4" class="data row1 col4" >6</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col5" class="data row1 col5" >1</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_col6" class="data row1 col6" >0</td>
#         <td id="T_fe9a9697_6805_11e8_bcd6_d07e353b3c60row1_c

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# Initial        False
# dtype: bool

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col0 {
#             background-color:  #fcfe66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col1 {
#             background-color:  #d2e866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col2 {
#             background-color:  #f2f866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col3 {
#             background-color:  #d8ec66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col4 {
#             background-color:  #e8f466;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col0 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col1 {
#             background-color:  #f9fc66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col2 {
#             background-color:  #fcfe66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col3 {
#             background-color:  #fbfd66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col4 {
#             background-color:  #fbfd66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col0 {
#             background-color:  #e6f266;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col1 {
#             background-color:  #f0f866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col2 {
#             background-color:  #eef666;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col3 {
#             background-color:  #e8f466;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col4 {
#             background-color:  #edf666;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row3_col0 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row3_col1 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row3_col2 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row3_col3 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row3_col4 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row4_col0 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row4_col1 {
#             background-color:  #fefe66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row4_col2 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row4_col3 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row4_col4 {
#             background-color:  #ffff66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row5_col0 {
#             background-color:  #e3f166;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row5_col1 {
#             background-color:  #e6f266;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row5_col2 {
#             background-color:  #ecf666;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row5_col3 {
#             background-color:  #f8fc66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row5_col4 {
#             background-color:  #ebf566;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row6_col0 {
#             background-color:  #f9fc66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row6_col1 {
#             background-color:  #cde666;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row6_col2 {
#             background-color:  #e4f266;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row6_col3 {
#             background-color:  #bede66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row6_col4 {
#             background-color:  #dbed66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row7_col0 {
#             background-color:  #edf666;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row7_col1 {
#             background-color:  #bdde66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row7_col2 {
#             background-color:  #d3e966;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row7_col3 {
#             background-color:  #dcee66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row7_col4 {
#             background-color:  #d1e866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row8_col0 {
#             background-color:  #52a866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row8_col1 {
#             background-color:  #dcee66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row8_col2 {
#             background-color:  #81c066;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row8_col3 {
#             background-color:  #b0d866;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row8_col4 {
#             background-color:  #9acc66;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row9_col0 {
#             background-color:  #008066;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row9_col1 {
#             background-color:  #008066;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row9_col2 {
#             background-color:  #008066;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row9_col3 {
#             background-color:  #008066;
#         }    #T_0191367a_6806_11e8_bcd6_d07e353b3c60row9_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_0191367a_6806_11e8_bcd6_d07e353b3c60" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" colspan=2>female</th>
#         <th class="col_heading level0 col2" colspan=2>male</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0</th>
#         <th class="col_heading level1 col1" >1</th>
#         <th class="col_heading level1 col2" >0</th>
#         <th class="col_heading level1 col3" >1</th>
#         <th class="col_heading level1 col4" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Embarked</th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0191367a_6806_11e8_bcd6_d07e353b3c60level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#         <th id="T_0191367a_6806_11e8_bcd6_d07e353b3c60level1_row0" class="row_heading level1 row0" >1</th>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col0" class="data row0 col0" >1</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col1" class="data row0 col1" >42</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col2" class="data row0 col2" >25</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col3" class="data row0 col3" >17</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row0_col4" class="data row0 col4" >85</td>
#     </tr>    <tr>
#         <th id="T_0191367a_6806_11e8_bcd6_d07e353b3c60level1_row1" class="row_heading level1 row1" >2</th>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col0" class="data row1 col0" >0</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col1" class="data row1 col1" >7</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col2" class="data row1 col2" >8</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col3" class="data row1 col3" >2</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row1_col4" class="data row1 col4" >17</td>
#     </tr>    <tr>
#         <th id="T_0191367a_6806_11e8_bcd6_d07e353b3c60level1_row2" class="row_heading level1 row2" >3</th>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col0" class="data row2 col0" >8</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col1" class="data row2 col1" >15</td>
#         <td id="T_0191367a_6806_11e8_bcd6_d07e353b3c60row2_col2" class=

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# Initial        False
# dtype: bool

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
data['Age_band'] = 0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')#checking the number of passenegers in each band
# Out:
# <style  type="text/css" >
#     #T_052795c2_6806_11e8_bcd6_d07e353b3c60row0_col0 {
#             background-color:  #ffff66;
#         }    #T_052795c2_6806_11e8_bcd6_d07e353b3c60row1_col0 {
#             background-color:  #d8ec66;
#         }    #T_052795c2_6806_11e8_bcd6_d07e353b3c60row2_col0 {
#             background-color:  #40a066;
#         }    #T_052795c2_6806_11e8_bcd6_d07e353b3c60row3_col0 {
#             background-color:  #289366;
#         }    #T_052795c2_6806_11e8_bcd6_d07e353b3c60row4_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_052795c2_6806_11e8_bcd6_d07e353b3c60" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Age_band</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_052795c2_6806_11e8_bcd6_d07e353b3c60level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_052795c2_6806_11e8_bcd6_d07e353b3c60row0_col0" class="data row0 col0" >382</td>
#     </tr>    <tr>
#         <th id="T_052795c2_6806_11e8_bcd6_d07e353b3c60level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_052795c2_6806_11e8_bcd6_d07e353b3c60row1_col0" class="data row1 col0" >325</td>
#     </tr>    <tr>
#         <th id="T_052795c2_6806_11e8_bcd6_d07e353b3c60level0_row2" class="row_heading level0 row2" >0</th>
#         <td id="T_052795c2_6806_11e8_bcd6_d07e353b3c60row2_col0" class="data row2 col0" >104</td>
#     </tr>    <tr>
#         <th id="T_052795c2_6806_11e8_bcd6_d07e353b3c60level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_052795c2_6806_11e8_bcd6_d07e353b3c60row3_col0" class="data row3 col0" >69</td>
#     </tr>    <tr>
#         <th id="T_052795c2_6806_11e8_bcd6_d07e353b3c60level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_052795c2_6806_11e8_bcd6_d07e353b3c60row4_col0" class="data row4 col0" >11</td>
#     </tr></tbody>
# </table>

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp']#family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1#Alone

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_052795c3_6806_11e8_bcd6_d07e353b3c60row0_col0 {
#             background-color:  #ffff66;
#         }    #T_052795c3_6806_11e8_bcd6_d07e353b3c60row1_col0 {
#             background-color:  #b9dc66;
#         }    #T_052795c3_6806_11e8_bcd6_d07e353b3c60row2_col0 {
#             background-color:  #54aa66;
#         }    #T_052795c3_6806_11e8_bcd6_d07e353b3c60row3_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_052795c3_6806_11e8_bcd6_d07e353b3c60" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Survived</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Fare_Range</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_052795c3_6806_11e8_bcd6_d07e353b3c60level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#         <td id="T_052795c3_6806_11e8_bcd6_d07e353b3c60row0_col0" class="data row0 col0" >0.197309</td>
#     </tr>    <tr>
#         <th id="T_052795c3_6806_11e8_bcd6_d07e353b3c60level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#         <td id="T_052795c3_6806_11e8_bcd6_d07e353b3c60row1_col0" class="data row1 col0" >0.303571</td>
#     </tr>    <tr>
#         <th id="T_052795c3_6806_11e8_bcd6_d07e353b3c60level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#         <td id="T_052795c3_6806_11e8_bcd6_d07e353b3c60row2_col0" class="data row2 col0" >0.454955</td>
#     </tr>    <tr>
#         <th id="T_052795c3_6806_11e8_bcd6_d07e353b3c60level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#         <td id="T_052795c3_6806_11e8_bcd6_d07e353b3c60row3_col0" class="data row3 col0" >0.581081</td>
#     </tr></tbody>
# </table>

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
train,test=train_test_split(data,test_size=0.3,random_state=0,stratify=data['Survived'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=data[data.columns[1:]]
Y=data['Survived']

# %%
test.head()
# Out:
#      Survived  Pclass  Sex  SibSp  Parch  Embarked  Initial  Age_band  \
# 421         0       3    0      0      0         2        0         1
# 618         1       2    1      2      1         0        2         0
# 116         0       3    0      0      0         2        0         4
# 310         1       1    1      0      0         1        2         1
# 57          0       3    0      0      0         1        0         1
#
#      Family_Size  Alone  Fare_cat
# 421            0      1         0
# 618            3      0         3
# 116            0      1         0
# 310            0      1         3
# 57             0      1         0

# %% [raw]
# t.head()

# %%
model = svm.SVC(kernel='rbf', C=1, gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
# Out:
# Accuracy for rbf SVM is  0.835820895522388
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model=svm.SVC(kernel='linear',C=0.1,gamma=0.1)
model.fit(train_X,train_Y)
prediction2=model.predict(test_X)
print('Accuracy for linear SVM is',metrics.accuracy_score(prediction2,test_Y))
# Out:
# Accuracy for linear SVM is 0.8171641791044776
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model=DecisionTreeClassifier()
model.fit(train_X,train_Y)
prediction4=model.predict(test_X)
print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction4,test_Y))
# Out:
# The accuracy of the Decision Tree is 0.8059701492537313

# %%
model=KNeighborsClassifier() 
model.fit(train_X,train_Y)
prediction5=model.predict(test_X)
print('The accuracy of the KNN is',metrics.accuracy_score(prediction5,test_Y))
# Out:
# The accuracy of the KNN is 0.832089552238806
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
model=GaussianNB()
model.fit(train_X,train_Y)
prediction6=model.predict(test_X)
print('The accuracy of the NaiveBayes is',metrics.accuracy_score(prediction6,test_Y))
# Out:
# The accuracy of the NaiveBayes is 0.8134328358208955
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_Y)
prediction7=model.predict(test_X)
print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction7,test_Y))
# Out:
# The accuracy of the Random Forests is 0.8134328358208955
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
kfold = KFold(n_splits=10, random_state=22) # k=10, split the data into 10 equal parts
xyz=[]
accuracy=[]
std=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree','Naive Bayes','Random Forest']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(),GaussianNB(),RandomForestClassifier(n_estimators=100)]
for i in models:
    model = i
    cv_result = cross_val_score(model,X,Y, cv = kfold,scoring = "accuracy")
    cv_result=cv_result
    xyz.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':xyz,'Std':std},index=classifiers)       
new_models_dataframe2
# Out:
#                       CV Mean       Std
# Linear Svm           0.793471  0.047797
# Radial Svm           0.828290  0.034427
# Logistic Regression  0.805843  0.021861
# KNN                  0.813783  0.041210
# Decision Tree        0.810350  0.026123
# Naive Bayes          0.801386  0.028999
# Random Forest        0.815943  0.030192

# %%
test = pd.read_csv('./data/test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test['Initial']=0
for i in test:
    test['Initial']=test.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

# %%
test.loc[(test.Age.isnull())&(test.Initial=='Mr'),'Age']=33
test.loc[(test.Age.isnull())&(test.Initial=='Mrs'),'Age']=36
test.loc[(test.Age.isnull())&(test.Initial=='Master'),'Age']=5
test.loc[(test.Age.isnull())&(test.Initial=='Miss'),'Age']=22
test.loc[(test.Age.isnull())&(test.Initial=='Other'),'Age']=46

# %%
test['Embarked'].fillna('S',inplace=True)

# %%
test.isnull().any()
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# Initial        False
# dtype: bool

# %%
test['Age_band'] = 0
test.loc[test['Age']<=16,'Age_band']=0
test.loc[(test['Age']>16)&(test['Age']<=32),'Age_band']=1
test.loc[(test['Age']>32)&(test['Age']<=48),'Age_band']=2
test.loc[(test['Age']>48)&(test['Age']<=64),'Age_band']=3
test.loc[test['Age']>64,'Age_band']=4

# %%
test['Family_Size']=0
test['Family_Size']=test['Parch']+test['SibSp']#family size
test['Alone']=0
test.loc[test.Family_Size==0,'Alone']=1#Alone

# %%
test['Fare'].fillna(method='ffill', inplace=True)

# %%
test['Fare_Range']=pd.qcut(test['Fare'],4)

# %%
test['Fare_cat']=0
test.loc[test['Fare']<=7.91,'Fare_cat']=0
test.loc[(test['Fare']>7.91)&(test['Fare']<=14.454),'Fare_cat']=1
test.loc[(test['Fare']>14.454)&(test['Fare']<=31),'Fare_cat']=2
test.loc[(test['Fare']>31)&(test['Fare']<=513),'Fare_cat']=3

# %%
test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
test['Sex'].replace(['male','female'],[0,1],inplace=True)
test['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
test['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
test.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)

# %%
test.head()
# Out:
#    Pclass  Sex  SibSp  Parch  Embarked  Initial  Age_band  Family_Size  Alone  \
# 0       3    0      0      0         2        0         2            0      1
# 1       3    1      1      0         0        1         2            1      0
# 2       2    0      0      0         2        0         3            0      1
# 3       3    0      0      0         0        0         1            0      1
# 4       3    1      1      1         0        1         1            2      0
#
#    Fare_cat
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1

# %%
test.dtypes
# Out:
# Pclass         int64
# Sex            int64
# SibSp          int64
# Parch          int64
# Embarked       int64
# Initial        int64
# Age_band       int64
# Family_Size    int64
# Alone          int64
# Fare_cat       int64
# dtype: object

# %%
predict_x = test[test.columns[0:]]
print(test_X.shape)
print(predict_x.shape)
predictions = model.predict(predict_x)
# Out:
# (268, 10)
# (418, 10)

# %%
predictions.shape
# Out:
# (418,)

# %%
test = pd.read_csv('./data/test.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
passengerId = test['PassengerId']
passengerId.head()
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# Name: PassengerId, dtype: object

# %%
test['Survived'] = predictions

# %%
test.drop(['Name','Age','Ticket','Fare','Cabin'],axis=1,inplace=True)

# %%
test.drop(['Pclass','Sex','SibSp','SibSp','SibSp'],axis=1,inplace=True)

# %%
test.drop(['Parch','Embarked'],axis=1,inplace=True)

# %%
test.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
test.to_csv('submission.csv')
